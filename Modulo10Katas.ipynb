# %% [markdown]
# ## Kata 10

# %%
from IPython import display
display.Image("https://raw.githubusercontent.com/mikaelzen/MisKatas/main/Tracebacks_SC.png")

# %%
from IPython import display
display.Image("https://raw.githubusercontent.com/mikaelzen/MisKatas/main/Try_except1.png")
